# %% [markdown]
# # __Reconstruction__
# 1) Class for puzzle pieces
# 2) Append the puzzle pieces to an array of puzzlePiece objects
# 3) Create a canvas
# 4) Paste the pieces to a canvas

# %% [markdown]
# ## puzzlePiece class
# Edge list: left,bottom,right,top

# %%
import cv2
import matplotlib.pyplot as plt

class puzzlePiece:
    def __init__(self, piece_id, contour, peaks_ids, center, angles, distances):
        self.piece_id = piece_id
        self.contour = contour
        self.corners = peaks_ids
        self.center = center
        self.contour_polar = (angles, distances)
        self.edges = []
        self.path = ""
        self.piece_type = ""

    def set_sides(self) -> None:
        """Sets the sides of the piece based on the edges."""
        if self.edges is not None:
            self.left = self.edges[0]
            self.bottom = self.edges[1]
            self.right = self.edges[2]
            self.top = self.edges[3]

    def get_piece_type(self) -> str:
        """Returns the type of the piece based on the number of edges."""
        if self.edges is not None:
            flat_edges_count = sum(1 for edge in self.edges if edge[3] == 0)

            match flat_edges_count:
                case 0: self.piece_type = "Middle"
                case 1: self.piece_type = "Border"
                case 2: self.piece_type = "Corner"

            return self.piece_type
    
    def rotate(self) -> None:
        "Rotates the piece by 90 degrees clockwise"
        piece = cv2.imread(self.path, cv2.IMREAD_UNCHANGED)
        piece = cv2.rotate(piece, cv2.ROTATE_90_CLOCKWISE)
        cv2.imwrite(self.path, piece)

        # Reassign sides
        self.left, self.bottom, self.right, self.top = (
            self.bottom, self.right, self.top, self.left
        )


    def __repr__(self):
        ret = ""
        ret += f"{self.piece_id}\n"
        """ret += f"Contour: {len(self.contour)}\n"
        ret += f"Corners: {self.corners}\n"
        ret += f"Edges: {self.edges}\n"
        ret += f"Type: {self.get_piece_type()}\n"""

        return ret

# %% [markdown]
# ## Populating the pieces array

# %%
#!/usr/bin/env python
# coding: utf-8

# In[94]:


import cv2
import numpy as np
import matplotlib.pyplot as plt
import os
from scipy.signal import find_peaks
from scipy.signal import savgol_filter
from scipy.ndimage import gaussian_filter1d
import pandas as pd
import math
import bisect


# ### Default image path
image_path = "images/hack2.png"


def display_image(title, image):
    plt.figure(figsize=(8, 8))
    plt.title(title)
    plt.axis('off')
    if len(image.shape) == 2 or image.shape[2] == 1:
        plt.imshow(image, cmap='gray')
    else:
        plt.imshow(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))
    plt.show()


# ## Basic reading image and display

# In[97]:

original_image = cv2.imread(image_path, cv2.IMREAD_COLOR)
if original_image is None:
    raise ValueError(f"Could not read image from {image_path}")


# ## Grayscale conversion

# In[98]:

gray_image = cv2.cvtColor(original_image, cv2.COLOR_BGR2GRAY)
# display_image("Grayscale Image", gray_image)


print("Threshold to separate pieces from background")
_, binary_image = cv2.threshold(gray_image, 30, 255, cv2.THRESH_BINARY)
# display_image("Binary Image", binary_image)


kernel = np.ones((12, 12), np.uint8)


# In[101]:


# Close = filling the holes
morph_image = cv2.morphologyEx(binary_image, cv2.MORPH_CLOSE, kernel)
# Open = removing the noise
morph_image = cv2.morphologyEx(morph_image, cv2.MORPH_OPEN, kernel)
# display_image("Morph Operations", morph_image)


# In[102]:


# print("Filling holes in puzzle pieces")
contours_fill, _ = cv2.findContours(morph_image, cv2.RETR_CCOMP, cv2.CHAIN_APPROX_SIMPLE)
for cnt in contours_fill:
    cv2.drawContours(morph_image, [cnt], 0, 255, -1)
# display_image("Filled Holes", morph_image)


# ## Contours finding

# In[103]:


contours, _ = cv2.findContours(morph_image, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_NONE)
# print(f"Found {len(contours)} potential puzzle pieces")


# In[104]:


# print("Filtering contours by size")
contours = sorted(contours, key=lambda x: cv2.contourArea(x), reverse=True)
if len(contours) > 1:
    reference_area = cv2.contourArea(contours[1])
    contours = [cnt for cnt in contours if cv2.contourArea(cnt) > reference_area / 3]
# print(f"After filtering: {len(contours)} puzzle pieces")

# In[105]:

# print("Drawing contours of the original image")
contour_image = original_image.copy()
cv2.drawContours(contour_image, contours, -1, (0, 255, 0), 2)


# In[106]:

output_folder_pieces = "images/extracted_pieces"
os.makedirs(output_folder_pieces, exist_ok=True)

output_folder_contours = "images/extracted_contours"
os.makedirs(output_folder_contours, exist_ok=True)

output_corner_folder = "images/extracted_corners"
os.makedirs(output_corner_folder, exist_ok=True)

output_plots_folder = "images/corner_plots"
os.makedirs(output_plots_folder, exist_ok=True)

output_edges_and_corner_folder = "images/edges_and_corners"
os.makedirs(output_edges_and_corner_folder, exist_ok=True)

# In[107]:

piece_images = []
for i, contour in enumerate(contours):
    mask = np.zeros_like(gray_image)
    cv2.drawContours(mask, [contour], 0, 255, -1)

    piece = np.zeros_like(original_image)
    piece[mask == 255] = original_image[mask == 255]

    x, y, w, h = cv2.boundingRect(contour)
    cropped_piece = piece[y:y + h, x:x + w]
    piece_images.append(cropped_piece)

    piece_path = os.path.join(output_folder_pieces, f"piece_{i + 1}.png")
    cv2.imwrite(piece_path, cropped_piece)

    # Save piece with contour
    contour_piece = cropped_piece.copy()
    mask_cropped = mask[y:y + h, x:x + w]
    cv2.drawContours(contour_piece, [contour - [x, y]], 0, (255, 0, 255), 1,
                     cv2.LINE_8)  # Pink, width 1, no anti-aliasing
    contour_path = os.path.join(output_folder_contours, f"contour_{i + 1}.png")
    cv2.imwrite(contour_path, contour_piece)


puzzle_piece_holder = []

for contours_indices in range(len(contours)):

    # In[108]:
    selected_image_index = contours_indices


    # In[109]:
    piece_images = []

    i = selected_image_index
    contour = contours[i]

    mask = np.zeros_like(gray_image)
    cv2.drawContours(mask, [contour], 0, 255, -1)

    piece = np.zeros_like(original_image)
    piece[mask == 255] = original_image[mask == 255]
    x, y, w, h = cv2.boundingRect(contour)
    cropped_piece = piece[y:y + h, x:x + w]
    piece_images.append(cropped_piece)

    piece_path = os.path.join(output_folder_pieces, f"piece_{i + 1}.png")
    cv2.imwrite(piece_path, cropped_piece)
    contour_piece = cropped_piece.copy()

    # display_image(f"Cropped piece {selected_image_index+1}", contour_piece)


    # In[110]:
    M = cv2.moments(contour)

    if M["m00"] == 0:
        print("ERROR")
    centroid_x = int(M["m10"] / M["m00"])
    centroid_y = int(M["m01"] / M["m00"])
    cv2.circle(contour_piece, (centroid_x - x, centroid_y - y), 2, (0, 0, 255), -1)
    # display_image(f"Centroid {i+1}", contour_piece)

    # In[113]:
    contour_points = contour - np.array([x, y])
    distances = []
    angles = []
    for point in contour:
        px, py = point[0]
        dx = px - centroid_x
        dy = py - centroid_y
        distance = np.sqrt(dx ** 2 + dy ** 2)
        angle = np.arctan2(dy, dx)
        distances.append(distance)
        angles.append(angle)

    angles_deg = np.array([(a * 180 / np.pi) % 360 for a in angles])

    distances = gaussian_filter1d(distances, sigma=2)
    delta_s = len(angles_deg) // 4

    angles_deg_s = np.roll(angles_deg, -delta_s)
    distances_s = np.roll(distances, -delta_s)

    # find the maxima
    min_distance_between_peaks = len(distances) // 20
    all_peak_indices, all_peak_properties = find_peaks(distances,                                 distance=min_distance_between_peaks,prominence=2)

    all_peak_indices_s, all_peak_properties_s = find_peaks(distances_s,                                 distance=min_distance_between_peaks,prominence=2)
    all_peak_indices_u = [(x+delta_s)%len(angles_deg) for x in all_peak_indices_s]
    all_peak_indices_f = [y for y in all_peak_indices_u if y not in all_peak_indices]

    for val in all_peak_indices_f:
        pos = np.searchsorted(all_peak_indices, val)
        all_peak_indices = np.insert(all_peak_indices, pos, val)

    # print(all_peak_properties)
    peak_angles = [angles_deg[peak_idx] for peak_idx in all_peak_indices]
    peak_distances = [distances[peak_idx] for peak_idx in all_peak_indices]

    # find the minima
    inverted_distances = [-d for d in distances]
    all_min_indices, all_min_properties = find_peaks(inverted_distances,
                                     distance=min_distance_between_peaks,prominence=0.1)

    min_angles = [angles_deg[min_idx] for min_idx in all_min_indices]
    min_distances = [distances[min_idx] for min_idx in all_min_indices]

    min_distances_avg = np.mean(min_distances)


    # In[122]:

    max_angle_diff = 25
    delCounter = 0

    remaining_peak_indices = all_peak_indices.tolist() if isinstance(all_peak_indices, np.ndarray) else all_peak_indices.copy()
    remaining_peak_angles = peak_angles.tolist() if isinstance(peak_angles, np.ndarray) else peak_angles.copy()
    remaining_peak_distances = peak_distances.tolist() if isinstance(peak_distances, np.ndarray) else peak_distances.copy()

    while True:
        removals_made = False

        for k in range(len(remaining_peak_angles)):
            if len(remaining_peak_angles) <= 1:
                break

            if remaining_peak_distances[k] <= min_distances_avg:
                print("removing a bottom peak")
                remaining_peak_indices.pop(k)
                remaining_peak_angles.pop(k)
                remaining_peak_distances.pop(k)
                break


            next_k = (k + 1) % len(remaining_peak_angles)  # Wrap-around logic

            if abs(remaining_peak_angles[next_k] - remaining_peak_angles[k]) < max_angle_diff:
                delCounter += 1
                removals_made = True

                if remaining_peak_distances[k] < remaining_peak_distances[next_k]:
                    remaining_peak_indices.pop(k)
                    remaining_peak_angles.pop(k)
                    remaining_peak_distances.pop(k)
                else:
                    remaining_peak_indices.pop(next_k)
                    remaining_peak_angles.pop(next_k)
                    remaining_peak_distances.pop(next_k)

                break


        if not removals_made or len(remaining_peak_angles) <= 1:
            break

    all_peak_indices = np.array(remaining_peak_indices) if isinstance(all_peak_indices, np.ndarray) else remaining_peak_indices
    peak_angles = np.array(remaining_peak_angles) if isinstance(peak_angles, np.ndarray) else remaining_peak_angles
    peak_distances = np.array(remaining_peak_distances) if isinstance(peak_distances, np.ndarray) else remaining_peak_distances

    new_min_indice = all_min_indices.copy()


    # In[126]:


    min_angles = [angles_deg[min_idx] for min_idx in new_min_indice]
    min_distances = [distances[min_idx] for min_idx in new_min_indice]


    # In[128]:


    def robust_pointiness(angles_deg, distances, peak_indices, window_small=5, window_large=15):
        pointiness_scores = []

        for peak_idx in peak_indices:
            small_left = max(0, peak_idx - window_small)
            small_right = min(len(distances) - 1, peak_idx + window_small)
            small_window = distances[small_left:small_right+1]

            large_left = max(0, peak_idx - window_large)
            large_right = min(len(distances) - 1, peak_idx + window_large)
            large_window = distances[large_left:large_right+1]

            peak_height = distances[peak_idx]
            small_avg = np.mean(small_window)
            large_avg = np.mean(large_window)

            pointiness = (peak_height - large_avg) * (small_avg - large_avg)
            pointiness_scores.append(pointiness)

        return pointiness_scores

    pointiness_scores = robust_pointiness(angles_deg, distances, all_peak_indices)

    top_4_indices = sorted(range(len(pointiness_scores)),
                          key=lambda i: pointiness_scores[i],
                          reverse=True)[:4]

    top_4_indices = sorted(top_4_indices)
    top_4_peak_indices = [all_peak_indices[i] for i in top_4_indices]

    temp = [int(w) for w in top_4_peak_indices]
    remaining_indices = [z for z in all_peak_indices if z not in temp]

    top_4_angles = [angles_deg[i] for i in top_4_peak_indices]
    top_4_distances = [distances[i] for i in top_4_peak_indices]

    os.makedirs(output_plots_folder, exist_ok=True)
    plt.savefig(os.path.join(output_plots_folder, f"plot_{selected_image_index + 1}.png"))

    # plt.show()

    # Print pointiness scores for all peaks
    for i, (angle, distance, score) in enumerate(zip(peak_angles, peak_distances, pointiness_scores)):
        print(f"Peak {i+1}: Angle = {angle:.2f}°, Distance = {distance:.2f}, Pointiness = {score:.2f}")
    print("\nTop 4 pointiest peaks:")
    for i, idx in enumerate(top_4_indices):
        print(f"Peak {idx+1}: Angle = {peak_angles[idx]:.2f}°, Distance = {peak_distances[idx]:.2f}, Pointiness = {pointiness_scores[idx]:.2f}")


    # In[130]:

    this_piece = puzzlePiece(
        contours_indices,
        contour,
        top_4_peak_indices,
        (centroid_x - x, centroid_y - y),
        angles_deg,
        distances
    )

    print(this_piece)


    # ## Edge type detection

    # In[131]:


    def exists_peak_between(a,b,peak_indices):
        if b < a:
            for p in peak_indices:
                if p > a or p < b:
                    print(f"Found maxima {p}")
                    return True

        else:
            for p in peak_indices:
                if p > a and p < b:
                    print(f"Found maxima {p}")
                    return True

            print("no peak between")
            return False


    # In[132]:

    resize_factor = 0.8

    def exists_minima_between(a,b,min_indices):
        if b < a:
            for p in min_indices:
                if p > a or p < b:
                    # hack to set distance smaller than custom threshold
                    if distances[p] < ((max(distances[a], distances[b])*resize_factor ) /1.41):
                        print(f"Found minima {p}")
                        return True
                    else:
                        return False

        else:
            for p in min_indices:
                if p > a and p < b:
                    if distances[p] < ((max(distances[a], distances[b])*resize_factor ) /1.41):
                        print(f"Found minima {p}")
                        return True
                    else:
                        return False

            print("no min between")
            return False


    # In[133]:


    edge_types = {0: "FLAT", 1: "IN", 2: "OUT"}
    print(all_min_indices)

    def get_edge_type(a, b):
        print("-----")
        print(a, b)
        print(angles_deg[a], angles_deg[b])

        print(remaining_indices)
        print([angles_deg[r] for r in remaining_indices])
        if exists_peak_between(a, b, remaining_indices):
            return 2
        else:
            if exists_minima_between(a, b, all_min_indices):
                return 1
            else:
                return 0


    # In[134]:


    class Edge:
        def __init__(self, edge_type, left_corner, right_corner):
            self.edge_type = edge_type
            self.left_corner = left_corner
            self.right_corner = right_corner


    # In[135]:


    edges = []

    for c, corner in enumerate(top_4_peak_indices):
        corner1 = top_4_peak_indices[c]
        corner2 = top_4_peak_indices[(c+1) % len(top_4_peak_indices)]

        edges.append((c, corner1, corner2, get_edge_type(corner1, corner2)))

    this_piece.edges = edges

    print(edges)


    # In[136]:


    for edge_id, start_idx, end_idx, edge_type in edges:
        print(angles_deg[start_idx], angles_deg[end_idx])



    # ## Draw edges types with Corners


    color_edge_corner_piece = contour_piece.copy()

    contour_points = contour.reshape(-1, 2)
    contour_points_shifted = contour_points - np.array([x, y])  # apply shift

    edge_colors = {
        0: (0, 0, 255),   # Blue for edge_type 0
        1: (255, 255, 0), # Yellow for edge_type 1
        2: (0, 255, 0)    # Green for edge_type 2
    }

    corner_color = (255, 0, 255)  # Purple color for corners
    for edge_id, start_idx, end_idx, edge_type in edges:
        start_px, start_py = contour_points[start_idx] - np.array([x, y])
        end_px, end_py = contour_points[end_idx] - np.array([x, y])

        color = edge_colors[edge_type]
        if start_idx < end_idx:
            indices = range(start_idx, end_idx)
        else:
            indices = list(range(start_idx, len(contour_points))) + list(range(0, end_idx))

        for idx in indices:
            px, py = contour_points_shifted[idx]
            color_edge_corner_piece[py, px] = color

        cv2.circle(color_edge_corner_piece, (start_px, start_py), 3, corner_color, -1)  # Start corner
        cv2.circle(color_edge_corner_piece, (end_px, end_py), 3, corner_color, -1)    # End corner

    edges_corners_path = os.path.join(output_edges_and_corner_folder, f"edges_corners_{selected_image_index + 1}.png")
    cv2.imwrite(edges_corners_path, color_edge_corner_piece)

    this_piece.edges = edges
    this_piece.path = piece_path
    this_piece.set_sides()
    puzzle_piece_holder.append(this_piece)
# Out:
# Threshold to separate pieces from background
# Peak 1: Angle = 227.91°, Distance = 82.61, Pointiness = 12.31
# Peak 2: Angle = 174.08°, Distance = 106.47, Pointiness = 1.76
# Peak 3: Angle = 130.53°, Distance = 89.96, Pointiness = 13.18
# Peak 4: Angle = 84.85°, Distance = 111.35, Pointiness = 4.24
# Peak 5: Angle = 43.21°, Distance = 89.74, Pointiness = 12.95
# Peak 6: Angle = 2.83°, Distance = 101.11, Pointiness = 0.85
# Peak 7: Angle = 313.24°, Distance = 91.16, Pointiness = 11.16
# Peak 8: Angle = 276.12°, Distance = 112.51, Pointiness = 4.13
#
# Top 4 pointiest peaks:
# Peak 1: Angle = 227.91°, Distance = 82.61, Pointiness = 12.31
# Peak 3: Angle = 130.53°, Distance = 89.96, Pointiness = 13.18
# Peak 5: Angle = 43.21°, Distance = 89.74, Pointiness = 12.95
# Peak 7: Angle = 313.24°, Distance = 91.16, Pointiness = 11.16
# 0
#
# [ 58 142 268 355 472 553 658 749]
# -----
# 95 311
# 227.91083782616775 130.53284093861072
# [np.int64(217), np.int64(419), np.int64(597), np.int64(796)]
# [np.float64(174.07541801801753), np.float64(84.85211517586369), np.float64(2.8341110163065135), np.float64(276.1155035662854)]
# Found maxima 217
# -----
# 311 513
# 130.53284093861072 43.210089391753925
# [np.int64(217), np.int64(419), np.int64(597), np.int64(796)]
# [np.float64(174.07541801801753), np.float64(84.85211517586369), np.float64(2.8341110163065135), np.float64(276.1155035662854)]
# Found maxima 419
# -----
# 513 715
# 43.210089391753925 313.2376089763395
# [np.int64(217), np.int64(419), np.int64(597), np.int64(796)]
# [np.float64(174.07541801801753), np.float64(84.85211517586369), np.float64(2.8341110163065135), np.float64(276.1155035662854)]
# Found maxima 597
# -----
# 715 95
# 313.2376089763395 227.91083782616775
# [np.int64(217), np.int64(419), np.int64(597), np.int64(796)]
# [np.float64(174.07541801801753), np.float64(84.85211517586369), np.float64(2.8341110163065135), np.float64(276.1155035662854)]
# Found maxima 796
# [(0, np.int64(95), np.int64(311), 2), (1, np.int64(311), np.int64(513), 2), (2, np.int64(513), np.int64(715), 2), (3, np.int64(715), np.int64(95), 2)]
# 227.91083782616775 130.53284093861072
# 130.53284093861072 43.210089391753925
# 43.210089391753925 313.2376089763395
# 313.2376089763395 227.91083782616775
# Peak 1: Angle = 221.68°, Distance = 96.92, Pointiness = 9.46
# Peak 2: Angle = 139.80°, Distance = 92.67, Pointiness = 6.60
# Peak 3: Angle = 88.32°, Distance = 102.05, Pointiness = 3.25
# Peak 4: Angle = 42.81°, Distance = 91.61, Pointiness = 14.23
# Peak 5: Angle = 356.57°, Distance = 100.16, Pointiness = 1.33
# Peak 6: Angle = 317.33°, Distance = 86.23, Pointiness = 11.38
# Peak 7: Angle = 272.81°, Distance = 102.10, Pointiness = 1.42
#
# Top 4 pointiest peaks:
# Peak 1: Angle = 221.68°, Distance = 96.92, Pointiness = 9.46
# Peak 2: Angle = 139.80°, Distance = 92.67, Pointiness = 6.60
# Peak 4: Angle = 42.81°, Distance = 91.61, Pointiness = 14.23
# Peak 6: Angle = 317.33°, Distance = 86.23, Pointiness = 11.38
# 1
#
# [ 42 180 288 383 478 576 652]
# -----
# 99 235
# 221.68221883166515 139.79983611390472
# [np.int64(337), np.int64(532), np.int64(701)]
# [np.float64(88.31531568210372), np.float64(356.5663696375495), np.float64(272.8063702517883)]
# no peak between
# -----
# 235 427
# 139.79983611390472 42.81419919322441
# [np.int64(337), np.int64(532), np.int64(701)]
# [np.float64(88.31531568210372), np.float64(356.5663696375495), np.float64(272.8063702517883)]
# Found maxima 337
# -----
# 427 611
# 42.81419919322441 317.32781508904117
# [np.int64(337), np.int64(532), np.int64(701)]
# [np.float64(88.31531568210372), np.float64(356.5663696375495), np.float64(272.8063702517883)]
# Found maxima 532
# -----
# 611 99
# 317.32781508904117 221.68221883166515
# [np.int64(337), np.int64(532), np.int64(701)]
# [np.float64(88.31531568210372), np.float64(356.5663696375495), np.float64(272.8063702517883)]
# Found maxima 701
# [(0, np.int64(99), np.int64(235), 0), (1, np.int64(235), np.int64(427), 2), (2, np.int64(427), np.int64(611), 2), (3, np.int64(611), np.int64(99), 2)]
# 221.68221883166515 139.79983611390472
# 139.79983611390472 42.81419919322441
# 42.81419919322441 317.32781508904117
# 317.32781508904117 221.68221883166515
# Peak 1: Angle = 223.18°, Distance = 88.05, Pointiness = 13.30
# Peak 2: Angle = 133.76°, Distance = 97.22, Pointiness = 13.49
# Peak 3: Angle = 52.74°, Distance = 88.37, Pointiness = 12.72
# Peak 4: Angle = 4.62°, Distance = 99.24, Pointiness = 1.15
# Peak 5: Angle = 314.01°, Distance = 80.95, Pointiness = 11.58
# Peak 6: Angle = 261.12°, Distance = 97.00, Pointiness = 0.38
#
# Top 4 pointiest peaks:
# Peak 1: Angle = 223.18°, Distance = 88.05, Pointiness = 13.30
# Peak 2: Angle = 133.76°, Distance = 97.22, Pointiness = 13.49
# Peak 3: Angle = 52.74°, Distance = 88.37, Pointiness = 12.72
# Peak 5: Angle = 314.01°, Distance = 80.95, Pointiness = 11.58
# 2
#
# [ 41 138 277 378 487 577]
# -----
# 77 209
# 223.18169703554818 133.76359239714384
# [np.int64(430), np.int64(638)]
# [np.float64(4.619923481660399), np.float64(261.1193408494797)]
# no peak between
# -----
# 209 331
# 133.76359239714384 52.74471054642291
# [np.int64(430), np.int64(638)]
# [np.float64(4.619923481660399), np.float64(261.1193408494797)]
# no peak between
# -----
# 331 531
# 52.74471054642291 314.0122396003602
# [np.int64(430), np.int64(638)]
# [np.float64(4.619923481660399), np.float64(261.1193408494797)]
# Found maxima 430
# -----
# 531 77
# 314.0122396003602 223.18169703554818
# [np.int64(430), np.int64(638)]
# [np.float64(4.619923481660399), np.float64(261.1193408494797)]
# Found maxima 638
# [(0, np.int64(77), np.int64(209), 0), (1, np.int64(209), np.int64(331), 0), (2, np.int64(331), np.int64(531), 2), (3, np.int64(531), np.int64(77), 2)]
# 223.18169703554818 133.76359239714384
# 133.76359239714384 52.74471054642291
# 52.74471054642291 314.0122396003602
# 314.0122396003602 223.18169703554818
# Peak 1: Angle = 218.32°, Distance = 77.94, Pointiness = 12.20
# Peak 2: Angle = 167.83°, Distance = 104.10, Pointiness = 3.02
# Peak 3: Angle = 124.80°, Distance = 98.79, Pointiness = 13.85
# Peak 4: Angle = 49.05°, Distance = 89.21, Pointiness = 10.79
# Peak 5: Angle = 11.63°, Distance = 103.90, Pointiness = 2.52
# Peak 6: Angle = 315.45°, Distance = 88.71, Pointiness = 13.75
# Peak 7: Angle = 260.24°, Distance = 94.18, Pointiness = 0.76
#
# Top 4 pointiest peaks:
# Peak 1: Angle = 218.32°, Distance = 77.94, Pointiness = 12.20
# Peak 3: Angle = 124.80°, Distance = 98.79, Pointiness = 13.85
# Peak 4: Angle = 49.05°, Distance = 89.21, Pointiness = 10.79
# Peak 6: Angle = 315.45°, Distance = 88.71, Pointiness = 13.75
# 3
#
# [ 49 116 233 376 501 614 719]
# -----
# 81 278
# 218.32011393677746 124.80401175271321
# [np.int64(183), np.int64(550), np.int64(778)]
# [np.float64(167.82854179141253), np.float64(11.633633998940438), np.float64(260.2382252249578)]
# Found maxima 183
# -----
# 278 469
# 124.80401175271321 49.05355423183141
# [np.int64(183), np.int64(550), np.int64(778)]
# [np.float64(167.82854179141253), np.float64(11.633633998940438), np.float64(260.2382252249578)]
# no peak between
# Found minima 376
# -----
# 469 666
# 49.05355423183141 315.45113854678726
# [np.int64(183), np.int64(550), np.int64(778)]
# [np.float64(167.82854179141253), np.float64(11.633633998940438), np.float64(260.2382252249578)]
# Found maxima 550
# -----
# 666 81
# 315.45113854678726 218.32011393677746
# [np.int64(183), np.int64(550), np.int64(778)]
# [np.float64(167.82854179141253), np.float64(11.633633998940438), np.float64(260.2382252249578)]
# Found maxima 778
# [(0, np.int64(81), np.int64(278), 2), (1, np.int64(278), np.int64(469), 1), (2, np.int64(469), np.int64(666), 2), (3, np.int64(666), np.int64(81), 2)]
# 218.32011393677746 124.80401175271321
# 124.80401175271321 49.05355423183141
# 49.05355423183141 315.45113854678726
# 315.45113854678726 218.32011393677746
# Peak 1: Angle = 213.50°, Distance = 81.03, Pointiness = 12.50
# Peak 2: Angle = 168.06°, Distance = 105.89, Pointiness = 1.78
# Peak 3: Angle = 128.26°, Distance = 89.34, Pointiness = 13.02
# Peak 4: Angle = 37.87°, Distance = 101.67, Pointiness = 12.10
# Peak 5: Angle = 322.62°, Distance = 89.52, Pointiness = 12.97
# Peak 6: Angle = 280.47°, Distance = 93.35, Pointiness = 1.72
#
# Top 4 pointiest peaks:
# Peak 1: Angle = 213.50°, Distance = 81.03, Pointiness = 12.50
# Peak 3: Angle = 128.26°, Distance = 89.34, Pointiness = 13.02
# Peak 4: Angle = 37.87°, Distance = 101.67, Pointiness = 12.10
# Peak 5: Angle = 322.62°, Distance = 89.52, Pointiness = 12.97
# 4
#
# [ 54 145 255 387 567 654]
# -----
# 111 290
# 213.4951846737412 128.26398878588066
# [np.int64(206), np.int64(697)]
# [np.float64(168.05582281155367), np.float64(280.4691742577114)]
# Found maxima 206
# -----
# 290 495
# 128.26398878588066 37.874983651098205
# [np.int64(206), np.int64(697)]
# [np.float64(168.05582281155367), np.float64(280.4691742577114)]
# no peak between
# Found minima 387
# -----
# 495 613
# 37.874983651098205 322.62419250445186
# [np.int64(206), np.int64(697)]
# [np.float64(168.05582281155367), np.float64(280.4691742577114)]
# no peak between
# -----
# 613 111
# 322.62419250445186 213.4951846737412
# [np.int64(206), np.int64(697)]
# [np.float64(168.05582281155367), np.float64(280.4691742577114)]
# Found maxima 697
# [(0, np.int64(111), np.int64(290), 2), (1, np.int64(290), np.int64(495), 1), (2, np.int64(495), np.int64(613), 0), (3, np.int64(613), np.int64(111), 2)]
# 213.4951846737412 128.26398878588066
# 128.26398878588066 37.874983651098205
# 37.874983651098205 322.62419250445186
# 322.62419250445186 213.4951846737412
# Peak 1: Angle = 234.75°, Distance = 90.76, Pointiness = 11.40
# Peak 2: Angle = 147.15°, Distance = 93.02, Pointiness = 12.00
# Peak 3: Angle = 106.24°, Distance = 106.85, Pointiness = 2.12
# Peak 4: Angle = 55.59°, Distance = 87.41, Pointiness = 11.47
# Peak 5: Angle = 321.84°, Distance = 87.94, Pointiness = 11.00
# Peak 6: Angle = 279.55°, Distance = 108.26, Pointiness = 3.16
#
# Top 4 pointiest peaks:
# Peak 1: Angle = 234.75°, Distance = 90.76, Pointiness = 11.40
# Peak 2: Angle = 147.15°, Distance = 93.02, Pointiness = 12.00
# Peak 4: Angle = 55.59°, Distance = 87.41, Pointiness = 11.47
# Peak 5: Angle = 321.84°, Distance = 87.94, Pointiness = 11.00
# 5
#
# [ 41 183 326 439 549 655]
# -----
# 87 284
# 234.75242494165377 147.15494169722226
# [np.int64(377), np.int64(703)]
# [np.float64(106.23884162969229), np.float64(279.5491339287359)]
# no peak between
# Found minima 183
# -----
# 284 489
# 147.15494169722226 55.591527747971384
# [np.int64(377), np.int64(703)]
# [np.float64(106.23884162969229), np.float64(279.5491339287359)]
# Found maxima 377
# -----
# 489 617
# 55.591527747971384 321.84277341263095
# [np.int64(377), np.int64(703)]
# [np.float64(106.23884162969229), np.float64(279.5491339287359)]
# no peak between
# -----
# 617 87
# 321.84277341263095 234.75242494165377
# [np.int64(377), np.int64(703)]
# [np.float64(106.23884162969229), np.float64(279.5491339287359)]
# Found maxima 703
# [(0, np.int64(87), np.int64(284), 1), (1, np.int64(284), np.int64(489), 2), (2, np.int64(489), np.int64(617), 0), (3, np.int64(617), np.int64(87), 2)]
# 234.75242494165377 147.15494169722226
# 147.15494169722226 55.591527747971384
# 55.591527747971384 321.84277341263095
# 321.84277341263095 234.75242494165377
# Peak 1: Angle = 219.42°, Distance = 93.40, Pointiness = 13.29
# Peak 2: Angle = 134.59°, Distance = 97.56, Pointiness = 11.90
# Peak 3: Angle = 45.00°, Distance = 94.11, Pointiness = 12.18
# Peak 4: Angle = 319.33°, Distance = 84.04, Pointiness = 10.37
# Peak 5: Angle = 275.53°, Distance = 93.34, Pointiness = 3.18
#
# Top 4 pointiest peaks:
# Peak 1: Angle = 219.42°, Distance = 93.40, Pointiness = 13.29
# Peak 2: Angle = 134.59°, Distance = 97.56, Pointiness = 11.90
# Peak 3: Angle = 45.00°, Distance = 94.11, Pointiness = 12.18
# Peak 4: Angle = 319.33°, Distance = 84.04, Pointiness = 10.37
# 6
#
# [ 39 189 355 487 591 640]
# -----
# 88 284
# 219.41739424346892 134.58780725859768
# [np.int64(631)]
# [np.float64(275.5275401516562)]
# no peak between
# Found minima 189
# -----
# 284 420
# 134.58780725859768 45.0
# [np.int64(631)]
# [np.float64(275.5275401516562)]
# no peak between
# -----
# 420 542
# 45.0 319.3250604347385
# [np.int64(631)]
# [np.float64(275.5275401516562)]
# no peak between
# -----
# 542 88
# 319.3250604347385 219.41739424346892
# [np.int64(631)]
# [np.float64(275.5275401516562)]
# Found maxima 631
# [(0, np.int64(88), np.int64(284), 1), (1, np.int64(284), np.int64(420), 0), (2, np.int64(420), np.int64(542), 0), (3, np.int64(542), np.int64(88), 2)]
# 219.41739424346892 134.58780725859768
# 134.58780725859768 45.0
# 45.0 319.3250604347385
# 319.3250604347385 219.41739424346892
# Peak 1: Angle = 218.97°, Distance = 86.37, Pointiness = 13.13
# Peak 2: Angle = 130.97°, Distance = 99.72, Pointiness = 12.65
# Peak 3: Angle = 47.88°, Distance = 97.59, Pointiness = 13.09
# Peak 4: Angle = 314.09°, Distance = 88.17, Pointiness = 11.01
# Peak 5: Angle = 276.04°, Distance = 104.49, Pointiness = 1.89
#
# Top 4 pointiest peaks:
# Peak 1: Angle = 218.97°, Distance = 86.37, Pointiness = 13.13
# Peak 2: Angle = 130.97°, Distance = 99.72, Pointiness = 12.65
# Peak 3: Angle = 47.88°, Distance = 97.59, Pointiness = 13.09
# Peak 4: Angle = 314.09°, Distance = 88.17, Pointiness = 11.01
# 7
#
# [ 56 202 376 553 677]
# -----
# 109 310
# 218.9667469937993 130.97173633351488
# [np.int64(723)]
# [np.float64(276.0376825214229)]
# no peak between
# Found minima 202
# -----
# 310 442
# 130.97173633351488 47.88296345253954
# [np.int64(723)]
# [np.float64(276.0376825214229)]
# no peak between
# -----
# 442 644
# 47.88296345253954 314.09061955080085
# [np.int64(723)]
# [np.float64(276.0376825214229)]
# no peak between
# Found minima 553
# -----
# 644 109
# 314.09061955080085 218.9667469937993
# [np.int64(723)]
# [np.float64(276.0376825214229)]
# Found maxima 723
# [(0, np.int64(109), np.int64(310), 1), (1, np.int64(310), np.int64(442), 0), (2, np.int64(442), np.int64(644), 1), (3, np.int64(644), np.int64(109), 2)]
# 218.9667469937993 130.97173633351488
# 130.97173633351488 47.88296345253954
# 47.88296345253954 314.09061955080085
# 314.09061955080085 218.9667469937993
# Peak 1: Angle = 229.09°, Distance = 98.79, Pointiness = 11.07
# Peak 2: Angle = 150.33°, Distance = 98.13, Pointiness = 7.76
# Peak 3: Angle = 63.15°, Distance = 90.29, Pointiness = 10.44
# Peak 4: Angle = 12.99°, Distance = 106.49, Pointiness = 2.56
# Peak 5: Angle = 318.11°, Distance = 90.26, Pointiness = 11.91
#
# Top 4 pointiest peaks:
# Peak 1: Angle = 229.09°, Distance = 98.79, Pointiness = 11.07
# Peak 2: Angle = 150.33°, Distance = 98.13, Pointiness = 7.76
# Peak 3: Angle = 63.15°, Distance = 90.29, Pointiness = 10.44
# Peak 5: Angle = 318.11°, Distance = 90.26, Pointiness = 11.91
# 8
#
# [103 299 433 553 702]
# -----
# 0 188
# 229.08561677997488 150.32691788792218
# [np.int64(490)]
# [np.float64(12.994616791916505)]
# no peak between
# Found minima 103
# -----
# 188 387
# 150.32691788792218 63.152705886651155
# [np.int64(490)]
# [np.float64(12.994616791916505)]
# no peak between
# Found minima 299
# -----
# 387 606
# 63.152705886651155 318.1060270956164
# [np.int64(490)]
# [np.float64(12.994616791916505)]
# Found maxima 490
# -----
# 606 0
# 318.1060270956164 229.08561677997488
# [np.int64(490)]
# [np.float64(12.994616791916505)]
# Found minima 702
# [(0, np.int64(0), np.int64(188), 1), (1, np.int64(188), np.int64(387), 1), (2, np.int64(387), np.int64(606), 2), (3, np.int64(606), np.int64(0), 1)]
# 229.08561677997488 150.32691788792218
# 150.32691788792218 63.152705886651155
# 63.152705886651155 318.1060270956164
# 318.1060270956164 229.08561677997488
# Peak 1: Angle = 227.77°, Distance = 86.93, Pointiness = 15.26
# Peak 2: Angle = 185.92°, Distance = 106.48, Pointiness = 2.17
# Peak 3: Angle = 142.59°, Distance = 84.66, Pointiness = 12.23
# Peak 4: Angle = 43.56°, Distance = 83.08, Pointiness = 13.24
# Peak 5: Angle = 357.80°, Distance = 104.06, Pointiness = 1.60
# Peak 6: Angle = 320.36°, Distance = 89.82, Pointiness = 12.83
#
# Top 4 pointiest peaks:
# Peak 1: Angle = 227.77°, Distance = 86.93, Pointiness = 15.26
# Peak 3: Angle = 142.59°, Distance = 84.66, Pointiness = 12.23
# Peak 4: Angle = 43.56°, Distance = 83.08, Pointiness = 13.24
# Peak 6: Angle = 320.36°, Distance = 89.82, Pointiness = 12.83
# 9
#
# [ 40 147 250 348 451 595]
# -----
# 0 183
# 227.7702157972002 142.59464336859145
# [np.int64(90), np.int64(404)]
# [np.float64(185.92458198198247), np.float64(357.7974018382342)]
# Found maxima 90
# -----
# 183 312
# 142.59464336859145 43.55587446906416
# [np.int64(90), np.int64(404)]
# [np.float64(185.92458198198247), np.float64(357.7974018382342)]
# no peak between
# -----
# 312 491
# 43.55587446906416 320.3558250428552
# [np.int64(90), np.int64(404)]
# [np.float64(185.92458198198247), np.float64(357.7974018382342)]
# Found maxima 404
# -----
# 491 0
# 320.3558250428552 227.7702157972002
# [np.int64(90), np.int64(404)]
# [np.float64(185.92458198198247), np.float64(357.7974018382342)]
# Found minima 595
# [(0, np.int64(0), np.int64(183), 2), (1, np.int64(183), np.int64(312), 0), (2, np.int64(312), np.int64(491), 2), (3, np.int64(491), np.int64(0), 1)]
# 227.7702157972002 142.59464336859145
# 142.59464336859145 43.55587446906416
# 43.55587446906416 320.3558250428552
# 320.3558250428552 227.7702157972002
# Peak 1: Angle = 234.62°, Distance = 84.06, Pointiness = 16.03
# Peak 2: Angle = 182.81°, Distance = 102.10, Pointiness = 0.13
# Peak 3: Angle = 132.14°, Distance = 83.95, Pointiness = 11.11
# Peak 4: Angle = 47.60°, Distance = 92.34, Pointiness = 13.44
# Peak 5: Angle = 5.53°, Distance = 93.34, Pointiness = 1.99
# Peak 6: Angle = 314.10°, Distance = 89.43, Pointiness = 12.26
#
# Top 4 pointiest peaks:
# Peak 1: Angle = 234.62°, Distance = 84.06, Pointiness = 16.03
# Peak 3: Angle = 132.14°, Distance = 83.95, Pointiness = 11.11
# Peak 4: Angle = 47.60°, Distance = 92.34, Pointiness = 13.44
# Peak 6: Angle = 314.10°, Distance = 89.43, Pointiness = 12.26
# 10
#
# [ 48 102 169 298 442 537 679]
# -----
# 0 209
# 234.61972779969886 132.13759477388828
# [np.int64(108), np.int64(486)]
# [np.float64(182.80637025178822), np.float64(5.527540151656172)]
# Found maxima 108
# -----
# 209 390
# 132.13759477388828 47.60256220249981
# [np.int64(108), np.int64(486)]
# [np.float64(182.80637025178822), np.float64(5.527540151656172)]
# no peak between
# Found minima 298
# -----
# 390 584
# 47.60256220249981 314.1048262897889
# [np.int64(108), np.int64(486)]
# [np.float64(182.80637025178822), np.float64(5.527540151656172)]
# Found maxima 486
# -----
# 584 0
# 314.1048262897889 234.61972779969886
# [np.int64(108), np.int64(486)]
# [np.float64(182.80637025178822), np.float64(5.527540151656172)]
# Found minima 679
# [(0, np.int64(0), np.int64(209), 2), (1, np.int64(209), np.int64(390), 1), (2, np.int64(390), np.int64(584), 2), (3, np.int64(584), np.int64(0), 1)]
# 234.61972779969886 132.13759477388828
# 132.13759477388828 47.60256220249981
# 47.60256220249981 314.1048262897889
# 314.1048262897889 234.61972779969886
# Peak 1: Angle = 250.56°, Distance = 89.77, Pointiness = 2.57
# Peak 2: Angle = 207.14°, Distance = 89.40, Pointiness = 12.16
# Peak 3: Angle = 130.30°, Distance = 102.56, Pointiness = 11.84
# Peak 4: Angle = 43.15°, Distance = 86.79, Pointiness = 10.47
# Peak 5: Angle = 3.43°, Distance = 100.16, Pointiness = 0.47
# Peak 6: Angle = 315.00°, Distance = 76.70, Pointiness = 11.31
#
# Top 4 pointiest peaks:
# Peak 2: Angle = 207.14°, Distance = 89.40, Pointiness = 12.16
# Peak 3: Angle = 130.30°, Distance = 102.56, Pointiness = 11.84
# Peak 4: Angle = 43.15°, Distance = 86.79, Pointiness = 10.47
# Peak 6: Angle = 315.00°, Distance = 76.70, Pointiness = 11.31
# 11
#
# [  3  58 188 399 526 637 721]
# -----
# 105 292
# 207.13513962207688 130.30131948270056
# [np.int64(16), np.int64(575)]
# [np.float64(250.55996517182382), np.float64(3.4336303624505224)]
# no peak between
# Found minima 188
# -----
# 292 487
# 130.30131948270056 43.1523897340054
# [np.int64(16), np.int64(575)]
# [np.float64(250.55996517182382), np.float64(3.4336303624505224)]
# no peak between
# Found minima 399
# -----
# 487 677
# 43.1523897340054 315.0
# [np.int64(16), np.int64(575)]
# [np.float64(250.55996517182382), np.float64(3.4336303624505224)]
# Found maxima 575
# -----
# 677 105
# 315.0 207.13513962207688
# [np.int64(16), np.int64(575)]
# [np.float64(250.55996517182382), np.float64(3.4336303624505224)]
# Found maxima 16
# [(0, np.int64(105), np.int64(292), 1), (1, np.int64(292), np.int64(487), 1), (2, np.int64(487), np.int64(677), 2), (3, np.int64(677), np.int64(105), 2)]
# 207.13513962207688 130.30131948270056
# 130.30131948270056 43.1523897340054
# 43.1523897340054 315.0
# 315.0 207.13513962207688
# Peak 1: Angle = 228.87°, Distance = 93.62, Pointiness = 9.87
# Peak 2: Angle = 153.15°, Distance = 88.16, Pointiness = 10.31
# Peak 3: Angle = 100.47°, Distance = 93.35, Pointiness = 2.28
# Peak 4: Angle = 46.08°, Distance = 74.16, Pointiness = 12.29
# Peak 5: Angle = 9.36°, Distance = 91.99, Pointiness = 2.60
# Peak 6: Angle = 318.42°, Distance = 81.79, Pointiness = 11.14
#
# Top 4 pointiest peaks:
# Peak 1: Angle = 228.87°, Distance = 93.62, Pointiness = 9.87
# Peak 2: Angle = 153.15°, Distance = 88.16, Pointiness = 10.31
# Peak 4: Angle = 46.08°, Distance = 74.16, Pointiness = 12.29
# Peak 6: Angle = 318.42°, Distance = 81.79, Pointiness = 11.14
# 12
#
# [ 93 238 346 414 506 606]
# -----
# 0 186
# 228.87125623198563 153.14557865948143
# [np.int64(290), np.int64(454)]
# [np.float64(100.46917425771142), np.float64(9.360190801913326)]
# no peak between
# Found minima 93
# -----
# 186 387
# 153.14557865948143 46.080924186660695
# [np.int64(290), np.int64(454)]
# [np.float64(100.46917425771142), np.float64(9.360190801913326)]
# Found maxima 290
# -----
# 387 553
# 46.080924186660695 318.4238712449307
# [np.int64(290), np.int64(454)]
# [np.float64(100.46917425771142), np.float64(9.360190801913326)]
# Found maxima 454
# -----
# 553 0
# 318.4238712449307 228.87125623198563
# [np.int64(290), np.int64(454)]
# [np.float64(100.46917425771142), np.float64(9.360190801913326)]
# [(0, np.int64(0), np.int64(186), 1), (1, np.int64(186), np.int64(387), 2), (2, np.int64(387), np.int64(553), 2), (3, np.int64(553), np.int64(0), 0)]
# 228.87125623198563 153.14557865948143
# 153.14557865948143 46.080924186660695
# 46.080924186660695 318.4238712449307
# 318.4238712449307 228.87125623198563
# Peak 1: Angle = 230.96°, Distance = 94.37, Pointiness = 17.24
# Peak 2: Angle = 136.37°, Distance = 87.32, Pointiness = 13.29
# Peak 3: Angle = 80.54°, Distance = 97.08, Pointiness = 4.58
# Peak 4: Angle = 46.40°, Distance = 85.91, Pointiness = 13.26
# Peak 5: Angle = 309.96°, Distance = 95.71, Pointiness = 13.00
#
# Top 4 pointiest peaks:
# Peak 1: Angle = 230.96°, Distance = 94.37, Pointiness = 17.24
# Peak 2: Angle = 136.37°, Distance = 87.32, Pointiness = 13.29
# Peak 4: Angle = 46.40°, Distance = 85.91, Pointiness = 13.26
# Peak 5: Angle = 309.96°, Distance = 95.71, Pointiness = 13.00
# 13
#
# [109 250 352 481 517 655]
# -----
# 0 204
# 230.9644871012531 136.37483478056942
# [np.int64(315)]
# [np.float64(80.53767779197439)]
# no peak between
# Found minima 109
# -----
# 204 387
# 136.37483478056942 46.39718102729638
# [np.int64(315)]
# [np.float64(80.53767779197439)]
# Found maxima 315
# -----
# 387 593
# 46.39718102729638 309.9575489308291
# [np.int64(315)]
# [np.float64(80.53767779197439)]
# no peak between
# Found minima 481
# -----
# 593 0
# 309.9575489308291 230.9644871012531
# [np.int64(315)]
# [np.float64(80.53767779197439)]
# [(0, np.int64(0), np.int64(204), 1), (1, np.int64(204), np.int64(387), 2), (2, np.int64(387), np.int64(593), 1), (3, np.int64(593), np.int64(0), 0)]
# 230.9644871012531 136.37483478056942
# 136.37483478056942 46.39718102729638
# 46.39718102729638 309.9575489308291
# 309.9575489308291 230.9644871012531
# Peak 1: Angle = 229.09°, Distance = 98.79, Pointiness = 14.98
# Peak 2: Angle = 138.65°, Distance = 99.09, Pointiness = 11.16
# Peak 3: Angle = 49.14°, Distance = 96.75, Pointiness = 12.88
# Peak 4: Angle = 315.87°, Distance = 92.62, Pointiness = 11.12
#
# Top 4 pointiest peaks:
# Peak 1: Angle = 229.09°, Distance = 98.79, Pointiness = 14.98
# Peak 2: Angle = 138.65°, Distance = 99.09, Pointiness = 11.16
# Peak 3: Angle = 49.14°, Distance = 96.75, Pointiness = 12.88
# Peak 4: Angle = 315.87°, Distance = 92.62, Pointiness = 11.12
# 14
#
# [106 320 487 648]
# -----
# 0 211
# 229.08561677997488 138.65222278030632
# []
# []
# no peak between
# Found minima 106
# -----
# 211 413
# 138.65222278030632 49.1446237411043
# []
# []
# no peak between
# Found minima 320
# -----
# 413 552
# 49.1446237411043 315.86805144974556
# []
# []
# no peak between
# -----
# 552 0
# 315.86805144974556 229.08561677997488
# []
# []
# Found minima 648
# [(0, np.int64(0), np.int64(211), 1), (1, np.int64(211), np.int64(413), 1), (2, np.int64(413), np.int64(552), 0), (3, np.int64(552), np.int64(0), 1)]
# 229.08561677997488 138.65222278030632
# 138.65222278030632 49.1446237411043
# 49.1446237411043 315.86805144974556
# 315.86805144974556 229.08561677997488
# Peak 1: Angle = 230.62°, Distance = 85.79, Pointiness = 13.79
# Peak 2: Angle = 190.11°, Distance = 102.39, Pointiness = 1.72
# Peak 3: Angle = 138.69°, Distance = 86.84, Pointiness = 10.20
# Peak 4: Angle = 48.58°, Distance = 89.60, Pointiness = 13.73
# Peak 5: Angle = 9.55°, Distance = 102.22, Pointiness = 0.55
# Peak 6: Angle = 322.74°, Distance = 88.19, Pointiness = 10.68
#
# Top 4 pointiest peaks:
# Peak 1: Angle = 230.62°, Distance = 85.79, Pointiness = 13.79
# Peak 3: Angle = 138.69°, Distance = 86.84, Pointiness = 10.20
# Peak 4: Angle = 48.58°, Distance = 89.60, Pointiness = 13.73
# Peak 6: Angle = 322.74°, Distance = 88.19, Pointiness = 10.68
# 15
#
# [ 37 141 289 413 519 669]
# -----
# 0 192
# 230.6175805901268 138.69138598645128
# [np.int64(86), np.int64(464)]
# [np.float64(190.10503636503796), np.float64(9.554289672401765)]
# Found maxima 86
# -----
# 192 380
# 138.69138598645128 48.57633437499736
# [np.int64(86), np.int64(464)]
# [np.float64(190.10503636503796), np.float64(9.554289672401765)]
# no peak between
# Found minima 289
# -----
# 380 572
# 48.57633437499736 322.74471054642294
# [np.int64(86), np.int64(464)]
# [np.float64(190.10503636503796), np.float64(9.554289672401765)]
# Found maxima 464
# -----
# 572 0
# 322.74471054642294 230.6175805901268
# [np.int64(86), np.int64(464)]
# [np.float64(190.10503636503796), np.float64(9.554289672401765)]
# Found minima 669
# [(0, np.int64(0), np.int64(192), 2), (1, np.int64(192), np.int64(380), 1), (2, np.int64(380), np.int64(572), 2), (3, np.int64(572), np.int64(0), 1)]
# 230.6175805901268 138.69138598645128
# 138.69138598645128 48.57633437499736
# 48.57633437499736 322.74471054642294
# 322.74471054642294 230.6175805901268
# Peak 1: Angle = 223.48°, Distance = 78.84, Pointiness = 13.08
# Peak 2: Angle = 132.42°, Distance = 77.94, Pointiness = 11.78
# Peak 3: Angle = 84.64°, Distance = 96.33, Pointiness = 3.43
# Peak 4: Angle = 41.74°, Distance = 86.02, Pointiness = 13.24
# Peak 5: Angle = 316.88°, Distance = 86.09, Pointiness = 12.32
# Peak 6: Angle = 260.93°, Distance = 95.02, Pointiness = 1.52
#
# Top 4 pointiest peaks:
# Peak 1: Angle = 223.48°, Distance = 78.84, Pointiness = 13.08
# Peak 2: Angle = 132.42°, Distance = 77.94, Pointiness = 11.78
# Peak 4: Angle = 41.74°, Distance = 86.02, Pointiness = 13.24
# Peak 5: Angle = 316.88°, Distance = 86.09, Pointiness = 12.32
# 16
#
# [ 42 133 222 317 455 604]
# -----
# 78 191
# 223.4792303388562 132.42085249971657
# [np.int64(275), np.int64(658)]
# [np.float64(84.64417495714481), np.float64(260.9334972601838)]
# no peak between
# -----
# 191 365
# 132.42085249971657 41.742778059333055
# [np.int64(275), np.int64(658)]
# [np.float64(84.64417495714481), np.float64(260.9334972601838)]
# Found maxima 275
# -----
# 365 555
# 41.742778059333055 316.87787744728536
# [np.int64(275), np.int64(658)]
# [np.float64(84.64417495714481), np.float64(260.9334972601838)]
# no peak between
# Found minima 455
# -----
# 555 78
# 316.87787744728536 223.4792303388562
# [np.int64(275), np.int64(658)]
# [np.float64(84.64417495714481), np.float64(260.9334972601838)]
# Found maxima 658
# [(0, np.int64(78), np.int64(191), 0), (1, np.int64(191), np.int64(365), 2), (2, np.int64(365), np.int64(555), 1), (3, np.int64(555), np.int64(78), 2)]
# 223.4792303388562 132.42085249971657
# 132.42085249971657 41.742778059333055
# 41.742778059333055 316.87787744728536
# 316.87787744728536 223.4792303388562
# Peak 1: Angle = 217.23°, Distance = 93.37, Pointiness = 13.11
# Peak 2: Angle = 142.85°, Distance = 81.97, Pointiness = 11.06
# Peak 3: Angle = 84.86°, Distance = 89.27, Pointiness = 2.33
# Peak 4: Angle = 37.15°, Distance = 81.72, Pointiness = 12.92
# Peak 5: Angle = 315.00°, Distance = 83.77, Pointiness = 11.61
#
# Top 4 pointiest peaks:
# Peak 1: Angle = 217.23°, Distance = 93.37, Pointiness = 13.11
# Peak 2: Angle = 142.85°, Distance = 81.97, Pointiness = 11.06
# Peak 4: Angle = 37.15°, Distance = 81.72, Pointiness = 12.92
# Peak 5: Angle = 315.00°, Distance = 83.77, Pointiness = 11.61
# 17
#
# [ 37 201 327 425 528]
# -----
# 112 277
# 217.23483398157467 142.8533133019782
# [np.int64(380)]
# [np.float64(84.86362150757228)]
# no peak between
# Found minima 201
# -----
# 277 470
# 142.8533133019782 37.14668669802178
# [np.int64(380)]
# [np.float64(84.86362150757228)]
# Found maxima 380
# -----
# 470 580
# 37.14668669802178 315.0
# [np.int64(380)]
# [np.float64(84.86362150757228)]
# no peak between
# -----
# 580 112
# 315.0 217.23483398157467
# [np.int64(380)]
# [np.float64(84.86362150757228)]
# [(0, np.int64(112), np.int64(277), 1), (1, np.int64(277), np.int64(470), 2), (2, np.int64(470), np.int64(580), 0), (3, np.int64(580), np.int64(112), 0)]
# 217.23483398157467 142.8533133019782
# 142.8533133019782 37.14668669802178
# 37.14668669802178 315.0
# 315.0 217.23483398157467
# Peak 1: Angle = 228.12°, Distance = 77.05, Pointiness = 12.15
# Peak 2: Angle = 189.56°, Distance = 96.09, Pointiness = 3.91
# Peak 3: Angle = 132.71°, Distance = 87.37, Pointiness = 13.35
# Peak 4: Angle = 50.62°, Distance = 85.60, Pointiness = 13.41
# Peak 5: Angle = 7.05°, Distance = 97.64, Pointiness = 4.09
# Peak 6: Angle = 318.54°, Distance = 78.97, Pointiness = 13.06
#
# Top 4 pointiest peaks:
# Peak 1: Angle = 228.12°, Distance = 77.05, Pointiness = 12.15
# Peak 3: Angle = 132.71°, Distance = 87.37, Pointiness = 13.35
# Peak 4: Angle = 50.62°, Distance = 85.60, Pointiness = 13.41
# Peak 6: Angle = 318.54°, Distance = 78.97, Pointiness = 13.06
# 18
#
# [ 35 135 278 407 513 610]
# -----
# 0 184
# 228.1221304621157 132.70938995736148
# [np.int64(79), np.int64(451)]
# [np.float64(189.5600964808863), np.float64(7.052306007841189)]
# Found maxima 79
# -----
# 184 363
# 132.70938995736148 50.61758059012683
# [np.int64(79), np.int64(451)]
# [np.float64(189.5600964808863), np.float64(7.052306007841189)]
# no peak between
# Found minima 278
# -----
# 363 550
# 50.61758059012683 318.54476645559487
# [np.int64(79), np.int64(451)]
# [np.float64(189.5600964808863), np.float64(7.052306007841189)]
# Found maxima 451
# -----
# 550 0
# 318.54476645559487 228.1221304621157
# [np.int64(79), np.int64(451)]
# [np.float64(189.5600964808863), np.float64(7.052306007841189)]
# [(0, np.int64(0), np.int64(184), 2), (1, np.int64(184), np.int64(363), 1), (2, np.int64(363), np.int64(550), 2), (3, np.int64(550), np.int64(0), 0)]
# 228.1221304621157 132.70938995736148
# 132.70938995736148 50.61758059012683
# 50.61758059012683 318.54476645559487
# 318.54476645559487 228.1221304621157
# Peak 1: Angle = 226.40°, Distance = 86.27, Pointiness = 11.88
# Peak 2: Angle = 135.44°, Distance = 90.49, Pointiness = 11.76
# Peak 3: Angle = 48.47°, Distance = 92.69, Pointiness = 11.68
# Peak 4: Angle = 324.90°, Distance = 89.60, Pointiness = 11.28
#
# Top 4 pointiest peaks:
# Peak 1: Angle = 226.40°, Distance = 86.27, Pointiness = 11.88
# Peak 2: Angle = 135.44°, Distance = 90.49, Pointiness = 11.76
# Peak 3: Angle = 48.47°, Distance = 92.69, Pointiness = 11.68
# Peak 4: Angle = 324.90°, Distance = 89.60, Pointiness = 11.28
# 19
#
# [ 55 219 411 448 581]
# -----
# 0 128
# 226.39718102729637 135.44414443311194
# []
# []
# no peak between
# -----
# 128 314
# 135.44414443311194 48.468229258917155
# []
# []
# no peak between
# Found minima 219
# -----
# 314 507
# 48.468229258917155 324.90418321297386
# []
# []
# no peak between
# Found minima 411
# -----
# 507 0
# 324.90418321297386 226.39718102729637
# []
# []
# [(0, np.int64(0), np.int64(128), 0), (1, np.int64(128), np.int64(314), 1), (2, np.int64(314), np.int64(507), 1), (3, np.int64(507), np.int64(0), 0)]
# 226.39718102729637 135.44414443311194
# 135.44414443311194 48.468229258917155
# 48.468229258917155 324.90418321297386
# 324.90418321297386 226.39718102729637
# Peak 1: Angle = 227.37°, Distance = 84.61, Pointiness = 12.17
# Peak 2: Angle = 138.70°, Distance = 97.41, Pointiness = 10.91
# Peak 3: Angle = 58.12°, Distance = 95.56, Pointiness = 9.57
# Peak 4: Angle = 331.70°, Distance = 88.14, Pointiness = 11.81
# Peak 5: Angle = 280.86°, Distance = 100.57, Pointiness = 2.20
#
# Top 4 pointiest peaks:
# Peak 1: Angle = 227.37°, Distance = 84.61, Pointiness = 12.17
# Peak 2: Angle = 138.70°, Distance = 97.41, Pointiness = 10.91
# Peak 3: Angle = 58.12°, Distance = 95.56, Pointiness = 9.57
# Peak 4: Angle = 331.70°, Distance = 88.14, Pointiness = 11.81
# 20
#
# [ 50 184 399 609 745]
# -----
# 97 294
# 227.3662479914558 138.70462744207714
# [np.int64(803)]
# [np.float64(280.86405992208773)]
# no peak between
# Found minima 184
# -----
# 294 496
# 138.70462744207714 58.12040315297726
# [np.int64(803)]
# [np.float64(280.86405992208773)]
# no peak between
# Found minima 399
# -----
# 496 697
# 58.12040315297726 331.6992442339936
# [np.int64(803)]
# [np.float64(280.86405992208773)]
# no peak between
# Found minima 609
# -----
# 697 97
# 331.6992442339936 227.3662479914558
# [np.int64(803)]
# [np.float64(280.86405992208773)]
# Found maxima 803
# [(0, np.int64(97), np.int64(294), 1), (1, np.int64(294), np.int64(496), 1), (2, np.int64(496), np.int64(697), 1), (3, np.int64(697), np.int64(97), 2)]
# 227.3662479914558 138.70462744207714
# 138.70462744207714 58.12040315297726
# 58.12040315297726 331.6992442339936
# 331.6992442339936 227.3662479914558
# Peak 1: Angle = 227.77°, Distance = 86.69, Pointiness = 13.25
# Peak 2: Angle = 142.39°, Distance = 76.26, Pointiness = 10.49
# Peak 3: Angle = 101.07°, Distance = 93.36, Pointiness = 3.34
# Peak 4: Angle = 38.55°, Distance = 80.75, Pointiness = 13.34
# Peak 5: Angle = 312.32°, Distance = 89.52, Pointiness = 13.32
#
# Top 4 pointiest peaks:
# Peak 1: Angle = 227.77°, Distance = 86.69, Pointiness = 13.25
# Peak 2: Angle = 142.39°, Distance = 76.26, Pointiness = 10.49
# Peak 4: Angle = 38.55°, Distance = 80.75, Pointiness = 13.34
# Peak 5: Angle = 312.32°, Distance = 89.52, Pointiness = 13.32
# 21
#
# [ 24 173 290 398 544]
# -----
# 83 258
# 227.7702157972002 142.38604315126727
# [np.int64(333)]
# [np.float64(101.07020257793937)]
# no peak between
# Found minima 173
# -----
# 258 453
# 142.38604315126727 38.550465296157725
# [np.int64(333)]
# [np.float64(101.07020257793937)]
# Found maxima 333
# -----
# 453 628
# 38.550465296157725 312.31622484053105
# [np.int64(333)]
# [np.float64(101.07020257793937)]
# no peak between
# Found minima 544
# -----
# 628 83
# 312.31622484053105 227.7702157972002
# [np.int64(333)]
# [np.float64(101.07020257793937)]
# [(0, np.int64(83), np.int64(258), 1), (1, np.int64(258), np.int64(453), 2), (2, np.int64(453), np.int64(628), 1), (3, np.int64(628), np.int64(83), 0)]
# 227.7702157972002 142.38604315126727
# 142.38604315126727 38.550465296157725
# 38.550465296157725 312.31622484053105
# 312.31622484053105 227.7702157972002
# Peak 1: Angle = 218.07°, Distance = 75.57, Pointiness = 10.72
# Peak 2: Angle = 132.71°, Distance = 87.37, Pointiness = 12.89
# Peak 3: Angle = 43.18°, Distance = 88.05, Pointiness = 13.46
# Peak 4: Angle = 317.12°, Distance = 76.14, Pointiness = 9.12
# Peak 5: Angle = 256.76°, Distance = 87.07, Pointiness = 0.86
#
# Top 4 pointiest peaks:
# Peak 1: Angle = 218.07°, Distance = 75.57, Pointiness = 10.72
# Peak 2: Angle = 132.71°, Distance = 87.37, Pointiness = 12.89
# Peak 3: Angle = 43.18°, Distance = 88.05, Pointiness = 13.46
# Peak 4: Angle = 317.12°, Distance = 76.14, Pointiness = 9.12
# 22
#
# [ 38 153 313 456 589]
# -----
# 72 244
# 218.07278187399083 132.70938995736148
# [np.int64(643)]
# [np.float64(256.7594800848128)]
# no peak between
# Found minima 153
# -----
# 244 369
# 132.70938995736148 43.18169703554817
# [np.int64(643)]
# [np.float64(256.7594800848128)]
# no peak between
# -----
# 369 542
# 43.18169703554817 317.12109639666147
# [np.int64(643)]
# [np.float64(256.7594800848128)]
# no peak between
# Found minima 456
# -----
# 542 72
# 317.12109639666147 218.07278187399083
# [np.int64(643)]
# [np.float64(256.7594800848128)]
# Found maxima 643
# [(0, np.int64(72), np.int64(244), 1), (1, np.int64(244), np.int64(369), 0), (2, np.int64(369), np.int64(542), 1), (3, np.int64(542), np.int64(72), 2)]
# 218.07278187399083 132.70938995736148
# 132.70938995736148 43.18169703554817
# 43.18169703554817 317.12109639666147
# 317.12109639666147 218.07278187399083
# Peak 1: Angle = 236.14°, Distance = 90.65, Pointiness = 12.10
# Peak 2: Angle = 144.16°, Distance = 88.04, Pointiness = 10.13
# Peak 3: Angle = 52.62°, Distance = 89.54, Pointiness = 10.24
# Peak 4: Angle = 325.27°, Distance = 90.25, Pointiness = 9.56
#
# Top 4 pointiest peaks:
# Peak 1: Angle = 236.14°, Distance = 90.65, Pointiness = 12.10
# Peak 2: Angle = 144.16°, Distance = 88.04, Pointiness = 10.13
# Peak 3: Angle = 52.62°, Distance = 89.54, Pointiness = 10.24
# Peak 4: Angle = 325.27°, Distance = 90.25, Pointiness = 9.56
# 23
#
# [ 91 279 473 665]
# -----
# 0 188
# 236.1363094311817 144.1623470457217
# []
# []
# no peak between
# Found minima 91
# -----
# 188 377
# 144.1623470457217 52.624192504451834
# []
# []
# no peak between
# Found minima 279
# -----
# 377 566
# 52.624192504451834 325.26514046021373
# []
# []
# no peak between
# Found minima 473
# -----
# 566 0
# 325.26514046021373 236.1363094311817
# []
# []
# Found minima 665
# [(0, np.int64(0), np.int64(188), 1), (1, np.int64(188), np.int64(377), 1), (2, np.int64(377), np.int64(566), 1), (3, np.int64(566), np.int64(0), 1)]
# 236.1363094311817 144.1623470457217
# 144.1623470457217 52.624192504451834
# 52.624192504451834 325.26514046021373
# 325.26514046021373 236.1363094311817

# %%
import matplotlib.pyplot as plt
from math import ceil

# Define subplot grid size
num_pieces = len(puzzle_piece_holder)
cols = 5  # Number of columns in the grid
rows = ceil((num_pieces + 1) / cols)  # Rows for pieces + 1 for the canvas

fig, axes = plt.subplots(rows, cols, figsize=(15, rows * 3))
axes = axes.flatten()

# Display each puzzle piece
for i, piece in enumerate(puzzle_piece_holder):
    if piece.path:
        image = cv2.imread(piece.path, cv2.IMREAD_UNCHANGED)
        axes[i].imshow(cv2.cvtColor(image, cv2.COLOR_BGRA2RGBA))
        axes[i].set_title(f"Piece ID: {piece.piece_id}")
        axes[i].axis('off')

# Display the final canvas
axes[num_pieces].imshow(cv2.cvtColor(canvas.astype(np.uint8), cv2.COLOR_BGRA2RGBA))
axes[num_pieces].set_title("Final Canvas")
axes[num_pieces].axis('off')

# Hide any unused subplots
for j in range(num_pieces + 1, len(axes)):
    axes[j].axis('off')

plt.tight_layout()
plt.show()

# %% [markdown]
# ## Defining the matrix of pieces

# %%
# Find multipliers
n = len(puzzle_piece_holder)
pairs = []
for i in range(1, int(n**0.5) + 1):
    if n % i == 0:
        pairs.append((i, n // i))

print("pairs: ",pairs)

# Find the number of border pieces
n_border_pieces = [piece for piece in puzzle_piece_holder if piece.get_piece_type() == "Border"]
print("Number of border pieces: ", len(n_border_pieces))

# Get the right pair
for pair in pairs:
    if len(n_border_pieces) == (pair[0] + pair[1]) * 2 - 8:
        print(f"Pair found: {pair}")
        break

# Define width and height
WIDTH = pair[0]
HEIGHT = pair[1]
puzzle_piece_matrix = np.empty((HEIGHT, WIDTH), dtype=object)
print(puzzle_piece_matrix)
# Out:
# pairs:  [(1, 24), (2, 12), (3, 8), (4, 6)]
# Number of border pieces:  12
# Pair found: (4, 6)
# [[None None None None]
#  [None None None None]
#  [None None None None]
#  [None None None None]
#  [None None None None]
#  [None None None None]]

# %% [markdown]
# ## Array of matchings
# Matching model: (piece1,piece2,edge1,edge2,score) \
# Edge model: (index,point1,point2,type:{0: "FLAT", 1: "IN", 2: "OUT"})

# %%
# Assuming puzzle_piece_holder is a list of puzzlePiece objects
matchings = [
    (
        next((piece for piece in puzzle_piece_holder if piece.piece_id == 19), None),
        next((piece for piece in puzzle_piece_holder if piece.piece_id == 18), None),
        (2, np.int64(314), np.int64(507), 1),
        (0, np.int64(0), np.int64(184), 2),
        1
    )
]

print(matchings[0][0].edges)
display_image("Piece1", cv2.imread(matchings[0][0].path))

print("top",matchings[0][0].top)
print("bottom",matchings[0][0].bottom)
print("left",matchings[0][0].left)
print("right",matchings[0][0].right)

print(matchings[0][1].edges)
display_image("Piece2", cv2.imread(matchings[0][1].path))

print("top",matchings[0][1].top)
print("bottom",matchings[0][1].bottom)
print("left",matchings[0][1].left)
print("right",matchings[0][1].right)

print(matchings[0][1].left)
# Out:
# [(0, np.int64(0), np.int64(128), 0), (1, np.int64(128), np.int64(314), 1), (2, np.int64(314), np.int64(507), 1), (3, np.int64(507), np.int64(0), 0)]
# top (3, np.int64(507), np.int64(0), 0)
# bottom (1, np.int64(128), np.int64(314), 1)
# left (0, np.int64(0), np.int64(128), 0)
# right (2, np.int64(314), np.int64(507), 1)
# [(0, np.int64(0), np.int64(184), 2), (1, np.int64(184), np.int64(363), 1), (2, np.int64(363), np.int64(550), 2), (3, np.int64(550), np.int64(0), 0)]
# top (3, np.int64(550), np.int64(0), 0)
# bottom (1, np.int64(184), np.int64(363), 1)
# left (0, np.int64(0), np.int64(184), 2)
# right (2, np.int64(363), np.int64(550), 2)
# (0, np.int64(0), np.int64(184), 2)

# %% [markdown]
# ## Matrix of pieces population
# Edge model: (index,point1,point2,type:{0: "FLAT", 1: "IN", 2: "OUT"}) \
# Matching model: (piece1,piece2,edge1,edge2,score) \

# %%
"""
Placing the corner pieces in the matrix
"""
# Put the first corner piece at the bottom left corner
puzzle_piece_matrix[HEIGHT - 1][0] = next((piece for piece in puzzle_piece_holder if piece.piece_id == 19), None) 
print("Bottom:",puzzle_piece_matrix[HEIGHT - 1][0].bottom[3])

while not (puzzle_piece_matrix[HEIGHT - 1][0].bottom[3] == 0 and puzzle_piece_matrix[HEIGHT - 1][0].left[3] == 0):
    puzzle_piece_matrix[HEIGHT - 1][0].rotate()
    print("Bottom",puzzle_piece_matrix[HEIGHT - 1][0].bottom[3])
    print("Top",puzzle_piece_matrix[HEIGHT - 1][0].top[3])
    print("Left",puzzle_piece_matrix[HEIGHT - 1][0].left[3])
    print("Right",puzzle_piece_matrix[HEIGHT - 1][0].right[3])

""" 
Fill out the left side of the puzzle 
"""
for i in range(HEIGHT - 2, 0,-1):
    print("index",i)
    if puzzle_piece_matrix[i + 1][0] is not None and matchings:
        selector_edge = puzzle_piece_matrix[i + 1][0].top
        selector_piece = puzzle_piece_matrix[i + 1][0]
        print("Selector piece",selector_piece)
        print("Selector edge",selector_edge)

        for matching in matchings:
            # Get maximum score
            score = 0
            best_matching = None

            print("matching",matching)
            if selector_edge in matching and matching[4] > score: 
                score = matching[4]
                print("Score:",score)
                best_matching = matching
                print("Best matching:",best_matching)

            print("Caca",best_matching)
            # Place the next piece in the matrix
            if best_matching[0] == selector_piece:
                puzzle_piece_matrix[i][0] = matching[1]
            else:
                puzzle_piece_matrix[i][0] = matching[0]
            
            # Reorient the piece
            if best_matching[2] == selector_edge:
                target = best_matching[3]
                print("Target:",target)
            else:
                target = best_matching[2]
                print("Target:",target)
            
            while puzzle_piece_matrix[i][0].bottom != target:
                puzzle_piece_matrix[i][0].rotate()
                print("Bottom",puzzle_piece_matrix[i][0].bottom[3])
                print("Top",puzzle_piece_matrix[i][0].top[3])
                print("Left",puzzle_piece_matrix[i][0].left[3])
                print("Right",puzzle_piece_matrix[i][0].right[3])
            
            matchings.remove(best_matching)


# Pretty print the puzzle_piece_matrix
print("Puzzle Piece Matrix:")
for row in puzzle_piece_matrix:
    print([str(piece.piece_id) if piece else "None" for piece in row])
# Out:
# Bottom: 0
# index 4
# index 3
# index 2
# index 1
# Puzzle Piece Matrix:
# ['None', 'None', 'None', 'None']
# ['None', 'None', 'None', 'None']
# ['None', 'None', 'None', 'None']
# ['None', 'None', 'None', 'None']
# ['18', 'None', 'None', 'None']
# ['19', 'None', 'None', 'None']

# %% [markdown]
# ## Canvas display
# Notes:
# - Pieces must be resized to 200,200 (free parameter)
# - Keep a margin of 100,100 (free parameter)

# %%
RESIZE = 200
canvas = np.ones((HEIGHT * RESIZE, WIDTH * RESIZE, 4)) * 255
top_left_x, top_left_y = 0, 0  # Position of top left piece

cursor_x = top_left_x
cursor_y = top_left_y

for i in range(0, len(puzzle_piece_matrix)):
    for j in range(0, len(puzzle_piece_matrix[i])):
        if type(puzzle_piece_matrix[i, j]) == puzzlePiece:
            piece = cv2.imread(puzzle_piece_matrix[i, j].path, cv2.IMREAD_UNCHANGED)
            piece = cv2.resize(piece, (RESIZE, RESIZE))

            # Transparent background
            alpha_channel = np.ones((piece.shape[0], piece.shape[1]), dtype=np.uint8) * 255
            mask = np.all(piece == [0, 0, 0], axis=-1)
            alpha_channel[mask] = 0
            piece = np.dstack((piece, alpha_channel))

            # Define the position of piece in canvas
            canvas[cursor_y:cursor_y + piece.shape[0], cursor_x:cursor_x + piece.shape[1]] = piece

        if j < WIDTH - 1:
            cursor_x += 200

    cursor_x = top_left_x
    cursor_y += 200

# Display the updated canvas
plt.imshow(cv2.cvtColor(canvas.astype(np.uint8), cv2.COLOR_BGRA2RGBA))
plt.title("Canvas with pasted puzzle pieces")
plt.axis("off")
plt.show()
